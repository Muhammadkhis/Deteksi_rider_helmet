# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/Muhammadkhis/modifikasi_cf.git
# Out:
# Cloning into 'modifikasi_cf'...
# remote: Enumerating objects: 20953, done.
# remote: Total 20953 (delta 0), reused 0 (delta 0), pack-reused 20953
# Receiving objects: 100% (20953/20953), 11.84 MiB | 15.49 MiB/s, done.
# Resolving deltas: 100% (14783/14783), done.

# %%
cd /content/modifikasi_cf/
# Out:
# /content/modifikasi_cf

# %%
pip install -e.
# Out:
# Obtaining file:///content/modifikasi_cf
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %% [markdown]
# **Dataset**

# %%
from IPython import display
display.clear_output()
from ultralytics import YOLO
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NAbaVLRzVgeymcvkJEw0")
project = rf.workspace("project-helm").project("ngindentimur")
version = project.version(15)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.2, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ngindentimur-15 in yolov8:: 100%|██████████| 3080/3080 [00:00<00:00, 4084.09it/s]

# %% [markdown]
# **Training** **Model**

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=/content/yolov8-myedit.yaml data=/content/datasets/data.yaml epochs=200 imgsz=960 plots=True save_crop=True batch=8
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.10 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=/content/yolov8l-small.yaml data={dataset.location}/data.yaml epochs=100 imgsz=960 plots=True device=0 batch=4
# Out:
# /content
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   1182208  ultralytics.nn.modules.block.SPPF            [512, 1024, 5]
# ...
