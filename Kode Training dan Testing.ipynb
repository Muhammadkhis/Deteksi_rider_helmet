# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/Muhammadkhis/modifikasi_cf.git
# Out:
# Cloning into 'modifikasi_cf'...
# remote: Enumerating objects: 20962, done.
# remote: Total 20962 (delta 0), reused 0 (delta 0), pack-reused 20962
# Receiving objects: 100% (20962/20962), 12.39 MiB | 8.80 MiB/s, done.
# Resolving deltas: 100% (14508/14508), done.

# %%
cd /content/modifikasi_cf/
# Out:
# /content/modifikasi_cf

# %%
pip install -e.
# Out:
# Obtaining file:///content/modifikasi_cf
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
from IPython import display
display.clear_output()
from ultralytics import YOLO
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NAbaVLRzVgeymcvkJEw0")
project = rf.workspace("project-helm").project("pengemudimotor")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# /content/datasets
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data='/content/datasets/data.yaml' epochs=100 imgsz=960 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 245MB/s]
# New https://pypi.org/project/ultralytics/8.2.20 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/model1-uji.zip /content/modifikasi_cf/runs/detect/val
# Out:
#   adding: content/modifikasi_cf/runs/detect/val/ (stored 0%)
#   adding: content/modifikasi_cf/runs/detect/val/confusion_matrix_normalized.png (deflated 41%)
#   adding: content/modifikasi_cf/runs/detect/val/val_batch1_labels.jpg (deflated 5%)
#   adding: content/modifikasi_cf/runs/detect/val/val_batch2_pred.jpg (deflated 4%)
#   adding: content/modifikasi_cf/runs/detect/val/confusion_matrix.png (deflated 42%)
#   adding: content/modifikasi_cf/runs/detect/val/R_curve.png (deflated 13%)
#   adding: content/modifikasi_cf/runs/detect/val/F1_curve.png (deflated 13%)
#   adding: content/modifikasi_cf/runs/detect/val/val_batch0_labels.jpg (deflated 5%)
#   adding: content/modifikasi_cf/runs/detect/val/P_curve.png (deflated 16%)
#   adding: content/modifikasi_cf/runs/detect/val/val_batch2_labels.jpg (deflated 5%)
#   adding: content/modifikasi_cf/runs/detect/val/val_batch0_pred.jpg (deflated 5%)
#   adding: content/modifikasi_cf/runs/detect/val/PR_curve.png (deflated 18%)
# ...

# %%
# !yolo task=detect mode=predict model=/content/best.pt conf=0.25 source={dataset.location}/test/images save=True save_crop=True
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/63 /content/datasets/pengemudimotor-2/test/images/frame0_jpg.rf.982a6222fbeadfe31b588636a1aec9b7.jpg: 544x960 6 Riders, 215.0ms
# image 2/63 /content/datasets/pengemudimotor-2/test/images/frame100793_jpg.rf.991942722cd2d17c183ac6f2ee6da1f1.jpg: 544x960 1 No_rider, 1 Rider, 44.6ms
# image 3/63 /content/datasets/pengemudimotor-2/test/images/frame11250_jpg.rf.5798c6020864c0d97127de46037f6499.jpg: 544x960 15 Riders, 44.5ms
# image 4/63 /content/datasets/pengemudimotor-2/test/images/frame13875_jpg.rf.ae3224919251e50ce4eaab54d7d26fad.jpg: 544x960 1 No_rider, 10 Riders, 41.0ms
# image 5/63 /content/datasets/pengemudimotor-2/test/images/frame14125_jpg.rf.8362e3971df2bf935dd8deb9344cb6ed.jpg: 544x960 18 Riders, 31.1ms
# ...

# %%
# !zip -r /content/predict-model1-.zip /content/modifikasi_cf/runs/detect/predict3
# Out:
#   adding: content/modifikasi_cf/runs/detect/predict3/ (stored 0%)
#   adding: content/modifikasi_cf/runs/detect/predict3/frame96500_jpg.rf.5b7f073fe7cb7d1b12e22c27e38af25a.jpg (deflated 4%)
#   adding: content/modifikasi_cf/runs/detect/predict3/frame11250_jpg.rf.5798c6020864c0d97127de46037f6499.jpg (deflated 4%)
#   adding: content/modifikasi_cf/runs/detect/predict3/frame94250_jpg.rf.c4d69224a8e665b2ca32906b4cf85e33.jpg (deflated 4%)
#   adding: content/modifikasi_cf/runs/detect/predict3/crops/ (stored 0%)
#   adding: content/modifikasi_cf/runs/detect/predict3/crops/No_rider/ (stored 0%)
#   adding: content/modifikasi_cf/runs/detect/predict3/crops/No_rider/frame13875_jpg.rf.jpg (deflated 3%)
#   adding: content/modifikasi_cf/runs/detect/predict3/crops/No_rider/frame33750_jpg.rf.jpg (deflated 11%)
#   adding: content/modifikasi_cf/runs/detect/predict3/crops/No_rider/frame31920_jpg.rf.jpg (deflated 4%)
# ...

# %%
# !yolo task=detect mode=predict model='/content/best.pt' data='/content/datasets/data.yaml'
# Out:
# WARNING ⚠️ 'source' argument is missing. Using default 'source=/content/modifikasi_cf/ultralytics/assets'.
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/2 /content/modifikasi_cf/ultralytics/assets/bus.jpg: 960x736 1 Rider, 127.3ms
# image 2/2 /content/modifikasi_cf/ultralytics/assets/zidane.jpg: 544x960 (no detections), 195.6ms
# Speed: 5.7ms preprocess, 161.4ms inference, 592.8ms postprocess per image at shape (1, 3, 544, 960)
# Results saved to /content/modifikasi_cf/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
